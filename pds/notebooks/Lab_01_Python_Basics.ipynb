# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  CELL 1 — SETUP  (Run this first every session)                        ║
# ╚══════════════════════════════════════════════════════════════════════════╝

# ─── STUDENT CONFIGURATION — Edit the 4 lines below ─────────────────────────
STUDENT_ID = "arjun22cs001"  # Your REVA student ID (e.g. arjun22cs001)
NAME       = "Arjun Sharma"  # Your full name
SECTION    = "BTech-CS-1A"   # Your section (e.g. BTech-CS-1A)
FACULTY_ID = "F001"          # Your faculty's ID (ask your faculty)
# ─────────────────────────────────────────────────────────────────────────────

LAB_NO = 1  # DO NOT CHANGE

# Mount Google Drive (click Allow when prompted)
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

# Download tutor kernel and exercise library
import os, urllib.request
_BASE = "https://raw.githubusercontent.com/sanchitnis/PDSTeachingAssistant/main/pds"
for _url, _path in [
    (f"{_BASE}/pds_ai_tutor.py",                  "/content/pds_ai_tutor.py"),
    (f"{_BASE}/exercises/pds_lab_exercises.json", "/content/pds_lab_exercises.json"),
]:
    if not os.path.exists(_path):
        print(f"Downloading {os.path.basename(_path)}...")
        urllib.request.urlretrieve(_url, _path)

# %run /content/pds_ai_tutor.py
tutor = PDS_Tutor(
    lab_no=LAB_NO, student_id=STUDENT_ID,
    name=NAME, section=SECTION, faculty_id=FACULTY_ID
)

# %% [markdown]
# # 🐍 Lab 1 — Writing Basic Python Programs
#
# | | |
# |---|---|
# | **Course** | Python for Data Science Lab (B25CS0102) |
# | **CO Mapping** | CO1 — Demonstrate basic Python constructs |
# | **Bloom's Level** | Apply (L3) |
# | **Estimated Time** | 30 minutes |
# | **Tools** | Python 3.x, Google Colab |
#
# ## Objectives
# By the end of this lab you will be able to:
# - Use arithmetic operators to build mathematical expressions
# - Write and call functions with parameters and return values
# - Apply the `round()` built-in for controlled precision

# %% [markdown]
# ## 📋 Problem Statement
#
# Write a function called **`celsius_to_fahrenheit(celsius)`** that converts a temperature from Celsius to Fahrenheit.
#
# ### Formula
# $$F = \left(C \times \frac{9}{5}\right) + 32$$
#
# ### Requirements
# - Accept a single argument `celsius` (float or int)
# - Return the Fahrenheit value **rounded to 2 decimal places**
# - Must work for positive, negative, and zero values
#
# ### Sample Test Cases
#
# | Input (°C) | Expected Output (°F) |
# |---|---|
# | 100 | 212.0 |
# | 0 | 32.0 |
# | 37 | 98.6 |
# | -40 | -40.0 |
#
# ### Constraints
# - Use the formula above — **do not hardcode** specific answers
# - Use `round()` with 2 decimal places
# - Remember to assign your function to `student_answer` at the end

# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  CELL 4 — YOUR SOLUTION  (Write your code here)                        ║
# ╚══════════════════════════════════════════════════════════════════════════╝

def celsius_to_fahrenheit(celsius):
    """
    Convert temperature from Celsius to Fahrenheit.

    Args:
        celsius (float): Temperature in degrees Celsius.

    Returns:
        float: Temperature in Fahrenheit, rounded to 2 decimal places.
    """
    # TODO: Write your formula here
    pass


# ─── Always assign your solution to student_answer ────────────────────────────
student_answer = celsius_to_fahrenheit

# Quick test — run to see if your function works for the sample case
if student_answer is not None:
    try:
        test_result = student_answer(100)
        print(f"celsius_to_fahrenheit(100) = {test_result}  (expected: 212.0)")
    except Exception as e:
        print(f"Error: {e}")

# %% [markdown]
# ## 🤖 How to Use the Tutor
#
# | Cell | Action | What Happens |
# |---|---|---|
# | **Cell 6** | Run `tutor.evaluate_answer(student_answer)` | AI tutor asks you a Socratic question — never gives the answer |
# | **Cell 7** | Run `tutor.give_hint(1)` | Get a scaffolded hint; change `1` → `2` → `3` → `4` → `5` for deeper hints |
# | **Cell 8** | Run `tutor.grade_exercise(student_answer)` | Automated grading + AI feedback + full rubric scorecard |
# | **Cell 9** | Run `tutor.show_progress()` | See your scores across all 9 labs |
#
# > **Rule**: The tutor will **never** write code for you. It will ask questions that help you discover the answer yourself.

# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  CELL 6 — SELF-CHECK  (Run when stuck — get a Socratic question)       ║
# ╚══════════════════════════════════════════════════════════════════════════╝

tutor.evaluate_answer(student_answer)

# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  CELL 7 — HINT  (Change level 1→2→3→4→5 for more guidance)            ║
# ╚══════════════════════════════════════════════════════════════════════════╝

tutor.give_hint(1)  # ← Change 1 to 2, 3, 4, or 5 for deeper hints

# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  CELL 8 — SUBMIT  (Run when you are ready to receive your grade)       ║
# ╚══════════════════════════════════════════════════════════════════════════╝

tutor.grade_exercise(student_answer)

# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  CELL 9 — PROGRESS  (Run anytime to see all lab scores)                ║
# ╚══════════════════════════════════════════════════════════════════════════╝

tutor.show_progress()
