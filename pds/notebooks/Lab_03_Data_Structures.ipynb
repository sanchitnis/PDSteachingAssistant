# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  CELL 1 — SETUP  (Run this first every session)                        ║
# ╚══════════════════════════════════════════════════════════════════════════╝

STUDENT_ID = "arjun22cs001"
NAME       = "Arjun Sharma"
SECTION    = "BTech-CS-1A"
FACULTY_ID = "F001"

LAB_NO = 3  # DO NOT CHANGE

from google.colab import drive
drive.mount('/content/drive', force_remount=False)

import os, urllib.request
_BASE = "https://raw.githubusercontent.com/sanchitnis/PDSTeachingAssistant/main/pds"
for _url, _path in [
    (f"{_BASE}/pds_ai_tutor.py",                  "/content/pds_ai_tutor.py"),
    (f"{_BASE}/exercises/pds_lab_exercises.json", "/content/pds_lab_exercises.json"),
]:
    if not os.path.exists(_path):
        urllib.request.urlretrieve(_url, _path)

# %run /content/pds_ai_tutor.py
tutor = PDS_Tutor(lab_no=LAB_NO, student_id=STUDENT_ID,
                  name=NAME, section=SECTION, faculty_id=FACULTY_ID)

# %% [markdown]
# # 🐍 Lab 3 — Manipulating Lists, Tuples, Sets, and Dictionaries
#
# | | |
# |---|---|
# | **Course** | Python for Data Science Lab (B25CS0102) |
# | **CO Mapping** | CO2 — Core data structures |
# | **Bloom's Level** | Analyze (L4) |
# | **Estimated Time** | 45 minutes |
#
# ## Objectives
# - Use `list`, `set`, `tuple`, and `dict` for practical data problems
# - Apply `sorted()`, `set()`, `len()`, `sum()` built-ins
# - Understand the difference between in-place and non-destructive operations

# %% [markdown]
# ## 📋 Problem Statement
#
# Write a function **`analyze_collection(data)`** that accepts a list of numbers and returns a dict:
#
# | Key | Description |
# |---|---|
# | `'sum'` | Sum of all numbers |
# | `'mean'` | Arithmetic mean **rounded to 2 decimal places** |
# | `'max'` | Maximum value |
# | `'min'` | Minimum value |
# | `'unique_count'` | Number of unique values — **use `set()`** |
# | `'sorted_asc'` | List sorted ascending (do **not** modify original) |
# | `'sorted_desc'` | List sorted descending |
#
# ### Sample
# ```python
# analyze_collection([4, 2, 7, 2, 9, 4, 1])
# # Expected:
# # {'sum': 29, 'mean': 4.14, 'max': 9, 'min': 1,
# #  'unique_count': 5,
# #  'sorted_asc': [1, 2, 2, 4, 4, 7, 9],
# #  'sorted_desc': [9, 7, 4, 4, 2, 2, 1]}
# ```
#
# > ⚠️ Use `sorted()` (returns new list) — **not** `list.sort()` (modifies in place)

# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  CELL 4 — YOUR SOLUTION                                                ║
# ╚══════════════════════════════════════════════════════════════════════════╝

def analyze_collection(data):
    """
    Analyze a list of numbers and return summary statistics.

    Args:
        data (list): A non-empty list of numbers.

    Returns:
        dict: sum, mean, max, min, unique_count, sorted_asc, sorted_desc.
    """
    # TODO: Compute each key and return them in a dict
    # Hint: use set(data) to find unique values
    # Hint: use sorted(data, reverse=True) for descending order
    pass


student_answer = analyze_collection

# Quick test
try:
    sample = [4, 2, 7, 2, 9, 4, 1]
    result = student_answer(sample)
    print(f"sum          = {result.get('sum')}  (expected: 29)")
    print(f"mean         = {result.get('mean')}  (expected: 4.14)")
    print(f"unique_count = {result.get('unique_count')}  (expected: 5)")
    print(f"sorted_asc   = {result.get('sorted_asc')}")
except Exception as e:
    print(f"Error: {e}")

# %% [markdown]
# ## 🤖 How to Use the Tutor
# | Cell | Action |
# |---|---|
# | **Cell 6** | `tutor.evaluate_answer(student_answer)` — Socratic hint |
# | **Cell 7** | `tutor.give_hint(1)` — change 1→5 for more guidance |
# | **Cell 8** | `tutor.grade_exercise(student_answer)` — full scorecard |
# | **Cell 9** | `tutor.show_progress()` — all lab scores |

# %%
tutor.evaluate_answer(student_answer)

# %%
tutor.give_hint(1)  # ← Change to 2, 3, 4, or 5 for deeper hints

# %%
tutor.grade_exercise(student_answer)

# %%
tutor.show_progress()
