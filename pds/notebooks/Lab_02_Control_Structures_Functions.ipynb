# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  CELL 1 — SETUP  (Run this first every session)                        ║
# ╚══════════════════════════════════════════════════════════════════════════╝

# ─── STUDENT CONFIGURATION — Edit the 4 lines below ─────────────────────────
STUDENT_ID = "arjun22cs001"  # Your REVA student ID
NAME       = "Arjun Sharma"  # Your full name
SECTION    = "BTech-CS-1A"   # Your section
FACULTY_ID = "F001"          # Your faculty's ID (ask your faculty)
# ─────────────────────────────────────────────────────────────────────────────

LAB_NO = 2  # DO NOT CHANGE

from google.colab import drive
drive.mount('/content/drive', force_remount=False)

import os, urllib.request
_BASE = "https://raw.githubusercontent.com/sanchitnis/PDSTeachingAssistant/main/pds"
for _url, _path in [
    (f"{_BASE}/pds_ai_tutor.py",                  "/content/pds_ai_tutor.py"),
    (f"{_BASE}/exercises/pds_lab_exercises.json", "/content/pds_lab_exercises.json"),
]:
    if not os.path.exists(_path):
        print(f"Downloading {os.path.basename(_path)}...")
        urllib.request.urlretrieve(_url, _path)

# %run /content/pds_ai_tutor.py
tutor = PDS_Tutor(lab_no=LAB_NO, student_id=STUDENT_ID,
                  name=NAME, section=SECTION, faculty_id=FACULTY_ID)

# %% [markdown]
# # 🐍 Lab 2 — Implementing Control Structures and Functions
#
# | | |
# |---|---|
# | **Course** | Python for Data Science Lab (B25CS0102) |
# | **CO Mapping** | CO1, CO2 — Conditional logic, loops, modular programming |
# | **Bloom's Level** | Apply (L3) |
# | **Estimated Time** | 40 minutes |
#
# ## Objectives
# - Use `if/elif/else` for multi-branch decision making
# - Apply the modulo operator `%` for divisibility testing
# - Write modular, reusable functions with clear return types

# %% [markdown]
# ## 📋 Problem Statement
#
# Write **two functions**:
#
# ### Function 1: `classify_number(n)`
# Returns:
# - `'positive'` if n > 0
# - `'negative'` if n < 0
# - `'zero'` if n == 0
#
# ### Function 2: `fizzbuzz(n)`
# Returns:
# - `'FizzBuzz'` if n is divisible by **both** 3 and 5
# - `'Fizz'` if divisible by 3 only
# - `'Buzz'` if divisible by 5 only
# - The **string** form of n otherwise (e.g. `'7'`, not `7`)
#
# ### How to assign
# ```python
# student_answer = {'classify': classify_number, 'fizzbuzz': fizzbuzz}
# ```
#
# ### Sample Tests
# | Call | Expected |
# |---|---|
# | `classify_number(42)` | `'positive'` |
# | `classify_number(-7)` | `'negative'` |
# | `classify_number(0)` | `'zero'` |
# | `fizzbuzz(15)` | `'FizzBuzz'` |
# | `fizzbuzz(9)` | `'Fizz'` |
# | `fizzbuzz(25)` | `'Buzz'` |
# | `fizzbuzz(7)` | `'7'` |
#
# > **⚠️ Critical**: In `fizzbuzz`, check divisibility by **15 first**, then 3, then 5.

# %%
# ╔══════════════════════════════════════════════════════════════════════════╗
# ║  CELL 4 — YOUR SOLUTION                                                ║
# ╚══════════════════════════════════════════════════════════════════════════╝

def classify_number(n):
    """
    Classify an integer as positive, negative, or zero.

    Args:
        n (int or float): Number to classify.

    Returns:
        str: 'positive', 'negative', or 'zero'.
    """
    # TODO: Write your if/elif/else logic here
    pass


def fizzbuzz(n):
    """
    Return FizzBuzz classification for a given integer.

    Args:
        n (int): Number to evaluate.

    Returns:
        str: 'FizzBuzz', 'Fizz', 'Buzz', or str(n).
    """
    # TODO: Check divisibility by 15 FIRST, then 3, then 5
    pass


# ─── Assign BOTH functions as a dict ─────────────────────────────────────────
student_answer = {'classify': classify_number, 'fizzbuzz': fizzbuzz}

# Quick tests
try:
    print(f"classify_number(42)  = {classify_number(42)}  (expected: positive)")
    print(f"fizzbuzz(15)         = {fizzbuzz(15)}  (expected: FizzBuzz)")
    print(f"fizzbuzz(7)          = {fizzbuzz(7)}  (expected: '7' as string)")
except Exception as e:
    print(f"Error: {e}")

# %% [markdown]
# ## 🤖 How to Use the Tutor
#
# | Cell | Action | What Happens |
# |---|---|---|
# | **Cell 6** | `tutor.evaluate_answer(student_answer)` | Socratic question from AI |
# | **Cell 7** | `tutor.give_hint(1)` — change level 1→5 | Scaffolded hint |
# | **Cell 8** | `tutor.grade_exercise(student_answer)` | Full rubric scorecard |
# | **Cell 9** | `tutor.show_progress()` | All lab scores |
#
# > The tutor will **never** write code for you.

# %%
tutor.evaluate_answer(student_answer)

# %%
tutor.give_hint(1)  # ← Change to 2, 3, 4, or 5 for deeper hints

# %%
tutor.grade_exercise(student_answer)

# %%
tutor.show_progress()
